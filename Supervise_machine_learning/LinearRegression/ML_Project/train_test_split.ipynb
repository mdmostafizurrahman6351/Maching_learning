# %% [markdown]
# <a href="https://colab.research.google.com/github/mdmostafizurrahman6351/Maching_learning/blob/main/LinearRegression/ML_Project/train_test_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# library import
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification

# %%
# data genarate
x, y = make_classification(n_samples=1000, n_features=10, n_classes=2, random_state=42)

# %%
x.shape

# %%
pd.DataFrame(x).head()

# %%
pd.DataFrame(y).head()

# %%
# data separate using train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
pd.DataFrame(x_train)

# %%
x_train.shape # train data 70%

# %%
x_test.shape # test data 30%

# %%
y_train.shape # train data 70%

# %%
y_test.shape # test data 30%
