# %% [markdown]
# <a href="https://colab.research.google.com/github/mdmostafizurrahman6351/Maching_learning/blob/main/Supervise_machine_learning/Classification/ML_Project/churn_predction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
# data load
url = "https://raw.githubusercontent.com/mdmostafizurrahman6351/Maching_learning/refs/heads/main/Supervise_machine_learning/Classification/Dataset/Bank%20Customer%20Churn%20Prediction.csv"
df = pd.read_csv(url)
print(df.shape)
df.head()

# %%
df.isnull().sum()

# %%
sns.countplot(x="churn", data=df)
plt.show()

# %%
df.describe()

# %%
df["churn"].value_counts()

# %%
sns.countplot(x="country", hue="churn", data=df)
plt.show()

# %%
sns.countplot(x="gender",hue="churn", data=df)
plt.show()

# %%
sns.countplot(x="credit_card",hue="churn", data=df)
plt.show()

# %%
x = df[["credit_score","country","gender","age","tenure","balance","products_number","credit_card","active_member","estimated_salary"]]
y = df["churn"]

# %%
numeric_features = ["credit_score","age","tenure","balance","products_number","estimated_salary"]
catgoric_feature = ["gender", "country"]

num_pipline = Pipeline([
    ("scaler", StandardScaler())
])

cat_pipline = Pipeline([
    ("onehot", OneHotEncoder())
])

preprocessor = ColumnTransformer([
    ("num", num_pipline, numeric_features),
    ("cat", cat_pipline, catgoric_feature)
])

model = Pipeline([
    ("preprocessing", preprocessor),
    ("classifier", LogisticRegression())
])


#train test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)



# model fit
model.fit(x_train, y_train)

# predict
y_pred = model.predict(x_test)

print("score: ", model.score(x_test, y_test))

# evulation
print("accuracy: ", accuracy_score(y_test, y_pred))
print("confusion matrix: \n", confusion_matrix(y_test, y_pred))
print("clifaction report: \n", classification_report(y_test, y_pred))

# %%
# using classification
numeric_features = ["credit_score","age","tenure","balance","products_number","estimated_salary"]
catgoric_feature = ["gender", "country"]

num_pipeline = Pipeline([
    ("scaller", StandardScaler())
])

cat_pipeline = Pipeline([
    ("onehot", OneHotEncoder(drop="first"))
])

preprocessor = ColumnTransformer([
    ("num", num_pipeline, numeric_features),
    ("cat", cat_pipeline, catgoric_feature)
])

model2 = Pipeline([
    ("preprocessing", preprocessor),
    ("classifier", DecisionTreeClassifier())
])

model2.fit(x_train, y_train)

y_pred2 = model2.predict(x_test)

print("score: ", model2.score(x_test, y_test))

# evulation
print("acoraci: ", accuracy_score(y_test, y_pred2))
print("confusion matrix: \n", confusion_matrix(y_test, y_pred))
print("clifaction report: \n", classification_report(y_test, y_pred))

# %%
# using randomforest classifier
numeric_features = ["credit_score","age","tenure","balance","products_number","estimated_salary"]
catgoric_feature = ["gender", "country"]

num_pipeline = Pipeline([
    ("scaller", StandardScaler())
])

cat_pipeline = Pipeline([
    ("onehot", OneHotEncoder(drop="first"))
])

preprocessor = ColumnTransformer([
    ("num", num_pipeline, numeric_features),
    ("cat", cat_pipeline, catgoric_feature)
])

model3 = Pipeline([
    ("preprocessing", preprocessor),
    ("classifier", RandomForestClassifier())
])

model3.fit(x_train, y_train)

y_pred3 = model3.predict(x_test)

print("score: ", model3.score(x_test, y_test))

# evulation
print("acoraci: ", accuracy_score(y_test, y_pred3))
print("confusion matrix: \n", confusion_matrix(y_test, y_pred))
print("clifaction report: \n", classification_report(y_test, y_pred))
